# %%
import json

with open("C:/Users/lwooten/Desktop/Relaying Material Python/materialList/MasterList.json", 'r') as file:
        masterList = json.load(file)
        
newDict = {}

for i in masterList:
    newDict[i] = masterList[i]['Desc']
    
print(newDict)

with open('C:/Users/lwooten/Desktop/Relaying Material Python/materialList/MasterList.json', 'w') as file:
    json.dump(newDict, file)
# Out:
# {'0': '', '0A': 'NEMA 1 enclosure, 60" h x 32" w x 22" d, complete with subpanels, front swinging panel with open position locking bar, 3-point latch with padlocking handle, mounting channels, ANSI 61 light gray exterior finish, and white interior finish', '0B': 'NEMA 1 enclosure, 46" h x 32" w x 22" d, complete with subpanels, front swinging panel with open position locking bar, 3-point latch with padlocking handle, mounting channels, ANSI 61 light gray exterior finish, and white interior finish', '0C': 'NEMA 1 enclosure, 78" h x 32" w x 22" d, complete with subpanels, front swinging panel with open position locking bar, 3-point latch with padlocking handle, mounting channels, ANSI 61 light gray exterior finish, and white interior finish', '0D': 'Two-post rack, seismic frame, 84" h x 28" w x 15" d, with 23" retima rails with #12-24 threaded holes, gray finish\r\nChatsworth 13883-103\r\nSee catalog cut', '1': 'Distance relay\r\nMounting: Horizontal Rack mount, 3 RU\r\nPower supply vo
# ...
